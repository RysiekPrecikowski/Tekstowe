# %%
from typing import List, Tuple
from enum import Enum, auto

# %%
class Action(Enum):
    ADD = auto()
    DELETE = auto()
    CHANGE = auto()
    NO_CHANGE = auto()

# %%
class Edit_table_cell:
    def __init__(self, i, j, parent = None):
        self.cost = i if j == 0 else j if i == 0 else None
        self.parent = parent
        self.action = \
            Action.DELETE if (j == 0 and i > 0) \
            else Action.ADD if (i == 0 and j > 0)\
            else Action.NO_CHANGE

        self.i = i
        self.j = j

    def __repr__(self):
        return str(self.cost)

    def __str__(self):
        return str(self.i) + ", " + str(self.j) + " -> " + str(self.cost) + " " + str(self.action)\
               + "\n" + str(self.parent)

def edit_distance(x, y, delta = lambda x, y : 0 if x == y else 1) -> Tuple[List[List[Edit_table_cell]], int]:
    edit_table = [[Edit_table_cell(i, j) for j in range(len(y) + 1)] for i in range(len(x) + 1)]


    for i in range (1, len(x) + 1):
        edit_table[i][0].parent = edit_table[i-1][0]
        x_i = x[i-1]
        for j in range(1, len(y) + 1):
            if i == 0:
                edit_table[0][j].parent = edit_table[0][j-1]

            y_j = y[j-1]

            cost = min(
                edit_table[i][j - 1].cost + 1,
                edit_table[i - 1][j].cost + 1,
                edit_table[i-1][j-1].cost + delta(x_i, y_j)
            )

            if cost == edit_table[i][j-1].cost + 1:
                cell = edit_table[i][j-1]
                edit_table[i][j].action = Action.ADD

            elif cost == edit_table[i-1][j].cost + 1:
                cell = edit_table[i-1][j]
                edit_table[i][j].action = Action.DELETE
            else:
                cell = edit_table[i-1][j-1]
                edit_table[i][j].action = Action.NO_CHANGE if delta(x_i, y_j) == 0 else Action.CHANGE

            edit_table[i][j].cost = cost
            edit_table[i][j].parent = cell

    return edit_table, edit_table[len(x)][len(y)].cost

def get_edit_sequence(x, y,  delta = lambda x, y : 0 if x == y else 1):
    edit_table, distance = edit_distance(x,y, delta)

    cell = edit_table[len(x)][len(y)]

    sequence = []

    while cell is not None:
        i, j = cell.i, cell.j
        if i == 0 and j == 0:
            break
        sequence.append((i, j, x[i-1], y[j-1], cell.action))
        cell = cell.parent
    # pprint(sequence[::-1])
    return sequence[::-1], distance

def visualize(x, y, delta = lambda x, y : 0 if x == y else 1):
    text = ""
    sequence, distance = get_edit_sequence(x, y, delta)
    print("\n" + x , "to", y, "distance:", distance, "\n")

    for i, j, lx, ly, action in sequence:
        # print(i, j, lx, ly, action)
        if action == Action.NO_CHANGE:
            text += lx

        if action == Action.CHANGE:
            print(text + " {"+ lx + "-->" + ly + "} " + x[j:])
            text += ly

        if action == Action.DELETE:
            print(text + " {--", lx+"} " + x[j+1:])

        if action == Action.ADD:
            print(text + " {++", ly+"} " + x[i:])
            text += ly

# %%
def lcs(x, y):
    return (len(x) + len(y) - edit_distance(x, y, lambda x, y: 0 if x==y else 2)[1])/2

# %%
test_cases = [('los', 'kloc'),
              ('Łódź', 'Lodz'),
              ('kwintesencja', 'quintessence'),
              ('ATGAATCTTACCGCCTCG', 'ATGAGGCTCTGGCCCCTG') ]

# %%
for f, t in test_cases:
    visualize(f, t, lambda x, y: 0 if x==y else 1)
    print("\nLCS",lcs(f, t),"\n")
# Out:
# los to kloc distance: 2
#
#  {++ k} los
# klo {s-->c}
#
# LCS 2.0
#
#
# Łódź to Lodz distance: 3
#
#  {Ł-->L} ódź
# L {ó-->o} dź
# Lod {ź-->z}
#
# LCS 1.0
#
#
# kwintesencja to quintessence distance: 5
#
#  {k-->q} wintesencja
# q {w-->u} intesencja
# quintes {++ s} encja
# quintessenc {j-->e}
# quintessence {-- a}
#
# LCS 8.0
#
#
# ATGAATCTTACCGCCTCG to ATGAGGCTCTGGCCCCTG distance: 7
#
# ATGA {A-->G} TCTTACCGCCTCG
# ATGAG {T-->G} CTTACCGCCTCG
# ATGAGGCT {++ C} TACCGCCTCG
# ATGAGGCTCT {A-->G} CGCCTCG
# ATGAGGCTCTG {++ G} CCGCCTCG
# ATGAGGCTCTGGCC {-- G} TCG
# ATGAGGCTCTGGCCCCT {-- C}
#
# LCS 13.0

# %%
from spacy.language import Language
from spacy.tokenizer import Tokenizer
from spacy.vocab import Vocab
from random import random

def remove_tokens(tokens):
    return [t for t in tokens if random() > 0.03 or t.text.isspace()]

with open('romeo-i-julia-700.txt') as file:
    text = file.read()
    vocab = Language(Vocab()).vocab
    tokenizer = Tokenizer(vocab)
    tokens = tokenizer(text)
    text1 = remove_tokens(tokens)
    text2 = remove_tokens(tokens)
    with open('text1.txt', 'w') as new_file:
        for token in text1:
            new_file.write(token.text_with_ws)
    with open('text2.txt', 'w') as new_file:
        for token in text2:
            new_file.write(token.text_with_ws)

# %%
def diff(x, y):
    L = [[0 if j == 0 or i == 0 else None for i in range(len(y) + 1)] for j in range(len(x) + 1)]

    for i in range(1, len(x) + 1):
        for j in range(1, len(y) + 1):
            if x[i - 1] == y[j - 1]:
                L[i][j] = L[i - 1][j - 1] + 1
            else:
                L[i][j] = max(L[i - 1][j], L[i][j - 1])

    def print_diff(i, j):
        if i >= 0 and j >= 0 and x[i] == y[j]:
            print_diff(i-1, j-1)

        elif j >= 0 and (i == 0 or L[i][j-1] >= L[i-1][j]):
            print_diff(i, j-1)
            print("x> ["+ str(j)+"]", y[j])

        elif i >= 0 and (j == 0 or L[i][j-1] < L[i-1][j]):
            print_diff(i-1, j)
            print("y< ["+ str(i)+"]", x[i])

    print_diff(len(x) - 1, len(y) - 1)

# %%
text1 = open("text1.txt").readlines()
text2 = open("text2.txt").readlines()

diff(text1, text2)
# Out:
# y< [3] tłum. Józef Paszkowski
#
# x> [3] tłum. Paszkowski
#
# y< [10]  * ESKALUS — panujący w Weronie
#
# x> [10]  * ESKALUS — książę panujący w Weronie
#
# y< [13]  * STARZEC — stryjeczny Kapuleta
#
# x> [13]  * STARZEC — stryjeczny brat Kapuleta
#
# y< [20]  * BALTAZAR — służący Romea
#
# x> [20]  * — Romea
#
# y< [28]  * PANI MONTEKI małżonka Montekiego
#
# x> [28]  * PANI MONTEKI — małżonka Montekiego
#
# y< [32]  * Obywatele weroneńscy, różne osoby płci obojej, liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby.
#
# x> [32]  * Obywatele weroneńscy, różne osoby płci liczący się do przyjaciół obu domów, maski, straż wojskowa i inne osoby.
#
# y< [37] Rzecz odbywa się przez większą część sztuki w przez część piątego aktu w Mantui.
#
# x> [37] Rzecz odbywa się przez większą część sztuki w Weronie, przez część piątego aktu w Mantui.
#
# y< [43] Przełożył Jan Kasprowicz
#
# x> [43] Przełożył Kasprowicz
#
# y< [46] Tam, gdzie się rzecz rozgrywa, w Weronie,
#
# x> [46] Tam, gdzie się rzecz ta w Weronie,
#
# y< [47] Do nowej zbrodni pchają złości dawne,
#
# y< [48] Plamiąc szlachetną krwią szlachetne dłonie
#
# x> [47] nowej zbrodni pchają złości dawne,
#
# x> [48] szlachetną krwią szlachetne dłonie
#
# y< [55] Tej ich miłości zbyt bolesny
#
# x> [55] Tej ich miłości przebieg zbyt bolesny
#
# y< [72] / Plac publiczny. Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze. /
#
# x> [72] Plac publiczny. Wchodzą Samson i Grzegorz uzbrojeni w tarcze i miecze. /
#
# y< [92] Kto zechce zadrzeć z nami, będzie musiał zadrżeć.
#
# x> [92] Kto zechce zadrzeć z będzie zadrżeć.
#
# y< [102] Tak, ale nie zaraz się dać rozruchać.
#
# x> [102] Tak, ale nie zaraz zwykłeś się dać rozruchać.
#
# y< [108]
#
# y< [110] GRZEGORZ
#
# y< [112] Rozruchać się tyle znaczy co się z miejsca; być walecznym to stać nieporuszenie: pojmuję więc, że skutkiem rozruchania twego będzie - drapnięcie.
#
# x> [112] Rozruchać się tyle znaczy co ruszyć się z miejsca; być walecznym jest to stać nieporuszenie: pojmuję więc, że skutkiem rozruchania się twego - drapnięcie.
#
# y< [115] SAMSON
#
# x> [113]
#
# y< [117] Te psy z domu Montekich rozruchać mię mogą tylko do stania na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego domu.
#
# x> [115] SAMSON
#
# x> [116]
#
# x> [117] Te psy z domu Montekich rozruchać mię mogą tylko do na miejscu. Będę jak mur dla każdego mężczyzny i każdej kobiety z tego
#
# y< [127] Prawda, dlatego to kobiety, jako najsłabsze, tulą się zawsze do muru. Ja też od muru ludzi Montekich, a kobiety Montekich przyprę do muru.
#
# x> [127] Prawda, dlatego to kobiety, jako najsłabsze, tulą się do muru. Ja też odtrącę od muru ludzi Montekich, a kobiety Montekich przyprę do muru.
#
# y< [137] Mniejsza mi o to, będę nieubłagany. Pobiwszy ludzi, wywrę wściekłość na kobietach: rzeź między sprawię.
#
# x> [137] Mniejsza mi o to, będę nieubłagany. Pobiwszy ludzi, wywrę wściekłość na kobietach: rzeź między nimi sprawię.
#
# y< [152] Tym lepiej, że się liczysz do zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się za instrument, bo oto nadchodzi dwóch Montekiego.
#
# x> [152] Tym lepiej, że się liczysz zwierząt; bo gdybyś się liczył do ryb, to byłbyś pewnie sztokfiszem. Weź no się instrument, bo oto nadchodzi dwóch domowników Montekiego.
#
# y< [153]
#
# y< [154] / Wchodzą Abraham i Baltazar. /
#
# x> [153]
#
# x> [154] Wchodzą Abraham i Baltazar. /
#
# y< [164] Gwoli
#
# x> [164] Gwoli drapania?
#
# y< [174] Ja bym się bać z twojej przyczyny!
#
# x> [174] Ja bym się miał bać z twojej przyczyny!
#
# y< [184] Marsa nastawię przechodząc; niech go sobie, jak chcą, tłumaczą.
#
# x> [184] Marsa im nastawię przechodząc; niech go sobie, jak chcą, tłumaczą.
#
# y< [221] Nie, panie; nie skrzywiłem się na was, tylko skrzywiłem się tak sobie.
#
# x> [221] mości panie; nie skrzywiłem się na was, skrzywiłem się tak sobie.
#
# y< [228] Zaczepki szukasz?
#
# x> [228] Zaczepki waść szukasz?
#
# y< [233] Zaczepki? nie.
#
# x> [233] nie.
#
# y< [238] Jeżeli jej szukasz, to jestem na waścine usługi. Mój pan tak dobry jak i
#
# x> [238] Jeżeli jej szukasz, to jestem na waścine usługi. Mój pan tak dobry jak i wasz.
#
# y< [248] Niech i tak będzie.
#
# x> [248] i tak będzie.
#
# y< [249]
#
# y< [250] / Benwolio ukazuje się w głębi. /
#
# x> [249]
#
# x> [250] Benwolio ukazuje się w głębi. /
#
# y< [281] Wchodzi Tybalt. /
#
# x> [281] / Wchodzi Tybalt. /
#
# y< [293] wraz ze mną rozdziel nim tych ludzi.
#
# x> [293] Albo wraz ze mną rozdziel nim tych ludzi.
#
# y< [303] / Walczą. Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady; wkrótce potem wchodzą mieszczanie z pałkami. /
#
# x> [303] / Walczą. Nadchodzi kilku przyjaciół obu partii i mieszają się do zwady; potem wchodzą mieszczanie z pałkami. /
#
# y< [306] PIERWSZY OBYWATEL
#
# x> [306] OBYWATEL
#
# y< [311] / Wchodzą i Pani /
#
# x> [311] / Wchodzą Kapulet i Pani Kapulet /
#
# y< [317] Mój hej!
#
# x> [317] Mój miecz! hej!
#
# y< [320] PANI KAPULET
#
# x> [320] KAPULET
#
# y< [353] Czy nie słyszycie? Ludzie czy zwierzęta,
#
# x> [353] Czy nie słyszycie? czy zwierzęta,
#
# y< [365] Porzucić swoje wygodne
#
# x> [365] Porzucić swoje wygodne przybory
#
# y< [376] raz wzywam wszystkich tu obecnych
#
# x> [376] Jeszcze raz wzywam wszystkich tu obecnych
#
# y< [377] Pod karą śmierci, się rozeszli.
#
# x> [377] Pod karą śmierci, aby się rozeszli.
#
# y< [385] Był żeś tu gdy się to zaczęło?
#
# x> [385] Był żeś tu wtedy, gdy się to zaczęło?
#
# y< [391] I wasi już się bili, kiedym nadszedł;
#
# x> [391] wasi już się bili, kiedym nadszedł;
#
# y< [392] Dobyłem broni, aby ich rozdzielić:
#
# y< [393] Wtem wpadł szalony Tybalt z gołym mieczem,
#
# x> [392] Dobyłem broni, aby ich rozdzielić:
#
# x> [393] Wtem wpadł szalony Tybalt gołym mieczem,
#
# y< [394] I harde zionąc mi w uszy wyzwanie,
#
# y< [395] Jął się wywijać nim i siec powietrze,
#
# x> [394] I harde mi w uszy wyzwanie,
#
# x> [395] Jął się wywijać nim i powietrze,
#
# y< [400] Aż książę nadszedł i rozdzielił wszystkich.
#
# x> [400] Aż książę nadszedł i wszystkich.
#
# y< [413] Troski wygnały mię z dala od
#
# x> [413] Troski wygnały mię z dala od domu
#
# y< [414] W sykomorowy ów gaj, co się ciągnie
#
# y< [415] Ku południowi od naszego miasta.
#
# y< [416] Tam, już rano, syn wasz się przechadzał.
#
# x> [414] W sykomorowy gaj, co się ciągnie
#
# x> [415] Ku południowi od naszego miasta.
#
# x> [416] Tam, już tak syn wasz się przechadzał.
#
# y< [430] Nieraz świcie już go tam widziano
#
# x> [430] Nieraz o świcie już go tam widziano
#
# y< [431] Łzami poranną rosę,
#
# x> [431] Łzami poranną mnożącego rosę,
#
# y< [446] Szanowny stryju, powód tego?
#
# x> [446] Szanowny stryju, znasz–że powód tego?
#
# y< [456] Wybadywał żeś go jakim sposobem?
#
# x> [456] Wybadywał żeś go sposobem?
#
# y< [461] Wybadywałem i sam, i przez drugich,
#
# x> [461] Wybadywałem i sam, przez drugich,
#
# y< [462] Lecz on jedyny powiernik swych smutków.
#
# y< [463] Tak im jest wierny, tak zamknięty w sobie,
#
# y< [464] Od otwartości wszelkiej tak daleki
#
# x> [462] Lecz jedyny powiernik swych smutków.
#
# x> [463] Tak im jest wierny, tak zamknięty w sobie,
#
# x> [464] Od wszelkiej tak daleki
#
# y< [467] I pełność swoją rozwinął przed słońcem.
#
# x> [467] I pełność rozwinął przed słońcem.
#
# y< [468] Gdybyśmy mogli dojść trosk zarodka,
#
# x> [468] Gdybyśmy mogli dojść tych trosk zarodka,
#
# y< [476] Oto nadchodzi. na stronę;
#
# x> [476] Oto nadchodzi. Odstąpcie na stronę;
#
# y< [482] Obyś w tej sprawie, co nam serce rani,
#
# x> [482] Obyś w sprawie, co nam serce rani,
#
# y< [483] Mógł być szczęśliwszym od nas! Pójdźmy, pani.
#
# y< [484]
#
# y< [485] / Wychodzą Monteki i Pani Monteki. /
#
# x> [483] Mógł być szczęśliwszym od nas! Pójdźmy,
#
# x> [484]
#
# x> [485] / Wychodzą Monteki Pani Monteki. /
#
# y< [507] Tak spiesznie w tamtą zboczyli ulicę?
#
# x> [507] spiesznie w tamtą zboczyli ulicę?
#
# y< [510] BENWOLIO
#
# y< [512] Tak jest. Lecz cóż tak chwile twoje dłuży?
#
# x> [511]
#
# x> [512] Tak jest. Lecz cóż tak chwile dłuży?
#
# y< [522] Miłość więc?
#
# x> [522] więc?
#
# y< [532]                         to? brak miłości?
#
# x> [532]                         Jak to? brak miłości?
#
# y< [537] Brak jej tam, skąd bym pragnął wzajemności.
#
# x> [537] Brak jej tam, skąd bym pragnął
#
# y< [551] Jakiś spór? mów mi o nim, wiem wszystko.
#
# x> [551] Jakiś spór? Nie mów mi o nim, wiem wszystko.
#
# y< [558] Jasna mgło! Zimny żarze! Martwy ruchu!
#
# x> [558] mgło! Zimny żarze! Martwy ruchu!
#
# y< [559] bez snu! Taką to w sobie zawiłość,
#
# y< [560] niełączność łączy moja miłość.
#
# x> [559] Śnie bez snu! Taką to w zawiłość,
#
# x> [560] Taką niełączność łączy moja miłość.
#
# y< [583] nawet przez odbitkę działa?
#
# x> [583] Miłości nawet przez odbitkę działa?
#
# y< [590] To żar, co w oku szczęśliwego płonie;
#
# x> [590] To żar, w oku szczęśliwego płonie;
#
# y< [591] Morze łez, w którym nieszczęśliwy tonie.
#
# y< [592] Czymże jest więcej? Istnym amalgamem,
#
# y< [593] Żółcią trawiącą i zbawczym balsamem.
#
# x> [591] łez, w którym nieszczęśliwy tonie.
#
# x> [592] Czymże jest więcej? Istnym amalgamem,
#
# x> [593] Żółcią trawiącą i zbawczym
#
# y< [596] / chce odejść
#
# x> [596] / odejść /
#
# y< [601]                         Zaczekaj! byś mi sprawił,
#
# x> [601]                         Zaczekaj! krzywdę byś mi sprawił,
#
# y< [607] Ach! ja nie jestem tu, nie jestem
#
# x> [607] Ach! ja nie jestem tu, nie jestem sobą;
#
# y< [608] To nie Romeo, co rozmawia z tobą.
#
# x> [608] nie Romeo, co rozmawia z tobą.
#
# y< [613] Kogóż to kochasz? mów!
#
# x> [613] Kogóż to mów!
#
# y< [614]
#
# x> [616] ROMEO
#
# y< [640] Gdym to pomyślał, nimeś mi powierzył.
#
# x> [640] to pomyślał, nimeś mi powierzył.
#
# y< [657] ona ma naturę Diany;
#
# x> [657] Kupida; ona ma naturę Diany;
#
# y< [658] Pod twardą zbroją wstydliwości swojej
#
# y< [659] Grotów miłości wcale się nie
#
# x> [658] Pod twardą zbroją wstydliwości swojej
#
# x> [659] Grotów wcale się nie boi;
#
# y< [660] Szydzi z nawału zaklęć oblężniczych;
#
# y< [661] Odpiera szturmy spojrzeń napastniczych;
#
# x> [660] Szydzi z nawału zaklęć oblężniczych;
#
# x> [661] szturmy spojrzeń
#
# y< [664] kiedy umrze, do grobu z nią zstąpi
#
# x> [664] Że kiedy umrze, do grobu z nią zstąpi
#
# y< [675] Tak jest; i skąpstwo to jest marnotrawstwem,
#
# x> [675] Tak jest; i skąpstwo jest marnotrawstwem,
#
# y< [679] Zbyt mądrze piękna: stąd istnym jest głazem.
#
# x> [679] Zbyt piękna: stąd istnym jest głazem.
#
# y< [686] Jest na to rada: przestań myśleć o niej.
#
# x> [686] Jest na rada: przestań myśleć o niej.
#
# y< [698] Rozpatrywania się w innych pięknościach.
#
# x> [698] Rozpatrywania się w pięknościach.
